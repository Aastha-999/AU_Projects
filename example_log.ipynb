# %%
with open("example_log.txt","r") as f:
  l=[]
  for i in f:
    s=f.read(14)
    l.append(s)
l
# Out:
# ['36.139.255.202',
#  '50.112.115.219',
#  '204.132.56.4 -',
#  '233.154.7.24 -',
#  '241.220.141.78',
#  '191.198.138.97',
#  '172.40.187.145',
#  '225.119.46.80 ',
#  '97.218.117.229',
#  '4.31.18.29 - -',
#  '124.66.196.14 ',
#  '103.40.29.163 ',
#  '215.73.240.165',
#  '236.187.70.48 ',
#  '183.186.55.245',
#  '74.191.205.248',
#  '70.163.195.102',
#  '94.75.8.56 - -',
#  '246.104.173.21',
#  '216.22.182.174',
#  '182.155.179.87',
#  '127.234.203.89',
#  '228.32.87.90 -',
#  '68.239.93.169 ',
#  '250.222.65.128',
#  '139.187.167.17',
#  '160.90.141.49 ',
#  '218.251.100.19',
#  '197.84.86.14 -',
#  '26.226.73.67 -',
#  '33.131.176.95 ',
#  '113.49.82.235 ',
#  '248.217.222.14',
#  '206.152.183.18',
#  '50.225.166.157',
#  '103.208.34.36 ',
#  '236.176.115.9 ',
#  '5.237.70.145 -',
#  '180.196.148.11',
#  '164.136.42.138',
#  '4.186.143.85 -',
#  '56.154.68.234 ',
#  '82.156.42.167 ',
#  '224.130.32.21 ',
#  '216.223.205.19',
#  '108.138.6.235 ',
#  '54.163.144.75 ',
# ...

# %%
sh=[]
for i in l:
  p= i.split()
  ip= p[0] if p else ""
  if '.' in ip:
    fp=ip.split('.')[0]
    if fp.isdigit() and int(fp)<20:
      sh.append(ip)
sh
# Out:
# ['4.31.18.29',
#  '5.237.70.145',
#  '4.186.143.85',
#  '7.205.198.134',
#  '2.98.108.99',
#  '17.192.186.123',
#  '19.137.101.141',
#  '5.175.199.96',
#  '19.219.60.226',
#  '3.208.33.106',
#  '16.153.33.150',
#  '19.190.115.218',
#  '0.153.103.45',
#  '12.194.245.108',
#  '2.96.57.90',
#  '4.223.194.188',
#  '6.0.14.128',
#  '12.115.103.178',
#  '5.181.86.241',
#  '3.29.197.164',
#  '1.240.103.127',
#  '9.49.15.69',
#  '9.168.30.192',
#  '1.149.44.202',
#  '6.71.195.192',
#  '2.189.10.201',
#  '7.145.173.45',
#  '0.254.152.197',
#  '5.40.110.55',
#  '5.38.234.254',
#  '17.92.13.79',
#  '12.48.79.71',
#  '11.36.42.176',
#  '6.72.235.92',
#  '4.68.239.140',
#  '1.30.105.246',
#  '0.177.146.178',
#  '3.172.107.70',
#  '2.176.114.240',
#  '5.8.146.209',
#  '14.0.215.165',
#  '9.238.11.123',
#  '6.84.193.66',
#  '5.40.104.181',
#  '18.154.65.30',
#  '2.220.43.118',
#  '8.59.183.202',
#  '10.182.249.118',
#  '16.204.153.175',
#  '11.229.61.134',
#  '16.209.56.250',
#  '5.183.124.144',
# ...
